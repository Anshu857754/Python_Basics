# %% [markdown]
# Data-Types

# %% [markdown]
# Integer

# %%
age = 35 
print(type(age))
print(age)
# Out:
# <class 'int'>
# 35

# %% [markdown]
# float

# %%
height= 3.15
print(type(height))
print(height)
# Out:
# <class 'float'>
# 3.15

# %% [markdown]
# String

# %%
name = "Anshu"
print(type(name))
print(name)
# Out:
# <class 'str'>
# Anshu

# %% [markdown]
# boolean

# %%
is_true = True
print(type(is_true))
# Out:
# <class 'bool'>

# %% [markdown]
# question1

# %%
result = "hello"+str(5) # by using type conversion i can chnge int 5 to str 5 
print(result)
# Out:
# hello5
