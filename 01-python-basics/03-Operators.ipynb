# %% [markdown]
# Operators

# %% [markdown]
# Arithmetic operations

# %%
a  = 100 
b = 15 
sum = a+b
sub = a-b
mul = a*b
div = a/b
floor_div = a//b
print(sum)
print(sub)
print(mul)
print(div)
print(floor_div)
# Out:
# 115
# 85
# 1500
# 6.666666666666667
# 6

# %%
## Comparison Operators
## == equal to operator
a=10
b=10

a == b
# Out:
# True

# %%
str1="Krish"
str2="Krish"

str1 == str2
# Out:
# True

# %%
# not equak to 
str1!=str2
# Out:
# False

# %%
# greater than

num1=45
num2=55

num1>num2
# Out:
# False

# %%
# less than

num1=45
num2=55

num1<num2
# Out:
# True

# %%
# greater than or eual to 
num1=45
num2=45

num1>=num2
# Out:
# True

# %%
# less than  or equal to 
num1<=num2
# Out:
# True

# %% [markdown]
# # logical operators

# %% [markdown]
# # and , not, or
#
# x = True
# y = True
#
# result = x and y
# print(result)

# %%
x = True
y = True

result = x and y 
print(result)
# Out:
# True

# %%
x = False
y = False

result = x and y 
print(result)
# Out:
# False

# %%
x = False
y = True

result = x or y 
print(result)
# Out:
# True

# %%
x = False
not x
print(result)
# Out:
# True
