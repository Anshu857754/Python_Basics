# %% [markdown]
# ## Import packages and modules

# %%
import math
math.sqrt(8)
# Out:
# 2.8284271247461903

# %%
from math import sqrt,pi
print(sqrt(81))
print(pi*(3))
# Out:
# 9.0
# 9.42477796076938

# %%
import numpy as np 
np.array([1,2,3,5])
# Out:
# array([1, 2, 3, 5])

# %%
from math import *  # star ka use iisliye kerte h jitne bhi functions math m honge sare insatall ho jayenge
sqrt(16)
pi
# Out:
# 3.141592653589793
