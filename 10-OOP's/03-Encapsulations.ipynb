# %% [markdown]
# ## Encapsulation And Abstraction
#
# Encapsulation and abstraction are two fundamental principles of Object-Oriented Programming (OOP) that
# help in designing robust, maintainable, and reusable code. Encapsulation involves bundling data and methods
# that operate on the data within a single unit, while abstraction involves hiding complex implementation details>
# and exposing only the necessary features.

# %% [markdown]
# ## Encapsulation
#
# Encapsulation is the concept of wrapping data (variables) and methods (functions) together as a single unit. It
# restricts direct access to some of the object's components, which is a means of preventing accidental
# interference and misuse of the data.

# %%
# Encapsulation by using getter and setters method 

# public, protected and private variables or acess modifiers

class Person:
    def __init__(self,name,age):
        self.name = name # public variables
        self.age = age # public variables

# ye function ke bahar hota h 
def get_name(person): 
        return person.name

person = Person("Anshu",21)
print(person.name)
print(person.age)

get_name(person)
# Out:
# Anshu
# 21
# 'Anshu'

# %%
# what are thr diffrent -diffrent type off variables are present over here
dir(person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'name']

# %% [markdown]
# ## ACCESS  PRIVATE  VARIABLE

# %%
# do bar undersocre . ke sath laga dunga to ye private ho jayega 
class Person:
    def __init__(self,name,age,gender):
        self.__name = name # private variables
        self.__age = age # private variables
        self.gender = gender # Pubic Varible

# hum outside the class kisi bhi private variables ko acess nhi ker sakte h. inside the class ker sakte h or derived
#  class bhi ho to bhi nhi ker sakte h

# def get_name(person):
#     return  person.__name

    def get_name(person):
        return  person.__name

person = Person("Anshu",21,"Male")
# do bar undersocre . ke sath laga dunga to ye private ho jayega 
class Person:
    def __init__(self,name,age,gender):
        self.__name = name # private variables
        self.__age = age # private variables
        self.gender = gender # Pubic Varible

# hum outside the class kisi bhi private variables ko acess nhi ker sakte h. inside teh class ker sakte h or derived
#  class bhi ho to bh nhi ker sakte h

# def get_name(person):
#     return  person.__name

    def get_name(person):
        return  person.__name

person = Person("Anshu",21,"Male")
print(person.get_name())
# Out:
# Anshu

# %% [markdown]
# # ACCESS THE PROTECTED VARIABLES

# %%
# ek bar undersocre . ke sath laga dunga to ye protected ho jayega .
class Person:
    def __init__(self, name, age, gender):
        self._name = name    # Protected variable
        self._age = age      # Protected variable
        self.gender = gender # Public variable

# hum outside the class kisi bhi variables ko acess  ker sakte h. but wo shi practice nhi hota h . inside the class ker sakte h or derived
#  class bhi ho to bh nhi ker sakte h.
    def get_name(self):
        return self._name    # Protected ko andar se access karo

person = Person("Anshu", 21, "Male")
print(person.get_name())    # Anshu
print(person.gender)        # Male
# Out:
# Anshu
# Male

# %% [markdown]
# ## Encapsulation with getter and setter

# %%
class Person:
    def __init__(self,name,age):
        self.__name = name # private variables
        self.__age = age # private variables

    # getter method for name
    def get_name(self):
        return self.__name
    
    # setter method for name
    def set_name(self,name):
        self.__name = name

    # getter method for age
    def get_age(self):
        return self.__age

    # setter method for age
    def set_age(self,age):
        if age >0:
            self.__age = age
        else:
            print("Age cannot be negative")

# Access and modify the private variables using the getter and setter methods

person = Person("Anshu", 21)

print(person.get_name())  # Anshu
print(person.get_age())   # 21

person.set_age(25)
print(person.get_age())   # 25

person.set_age(-21)
# Out:
# Anshu
# 21
# 25
# Age cannot be negative
