# %%
import logging
import sys

# Basic setup
logging.basicConfig(
    stream=sys.stdout,
    level=logging.DEBUG,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
)

# 3 alag alag loggers banao
logger_data  = logging.getLogger("data")
logger_model = logging.getLogger("model")
logger_api   = logging.getLogger("api")

# Data logger
logger_data.debug("Dataset load ho raha hai...")
logger_data.info("200 rows successfully load hui!")
logger_data.warning("Kuch missing values hain!")

# Model logger
logger_model.info("Model training shuru...")
logger_model.error("Model fit nahi ho raha!")

# API logger
logger_api.info("API call ho rahi hai...")
logger_api.critical("API band ho gayi!")
# Out:
# 2026-05-28 23:32:30,374 - data - DEBUG - Dataset load ho raha hai...
# 2026-05-28 23:32:30,375 - data - INFO - 200 rows successfully load hui!
# 2026-05-28 23:32:30,376 - data - WARNING - Kuch missing values hain!
# 2026-05-28 23:32:30,377 - model - INFO - Model training shuru...
# 2026-05-28 23:32:30,378 - model - ERROR - Model fit nahi ho raha!
# 2026-05-28 23:32:30,380 - api - INFO - API call ho rahi hai...
# 2026-05-28 23:32:30,380 - api - CRITICAL - API band ho gayi!
