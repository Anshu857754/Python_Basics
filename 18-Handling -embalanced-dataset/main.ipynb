# %% [markdown]
# ## Handling Imbalanced Dataset
#
# 1. Up Sampling
# 2. Down Sampling

# %%
import numpy as np
import pandas as pd

# Set the random seed for reproducibility
np.random.seed(123)

# Create a dataframe with two classes
n_samples = 10000
class_0_ratio = 0.9
n_class_0 = int(n_samples * class_0_ratio) # (1000 * 0.9) = 900 
n_class_1 = n_samples - n_class_0 # (1000-900)=100

# %%
n_class_0,n_class_1
# Out:
# (9000, 1000)

# %%
## CREATE MY DATAFRAME WITH IMBALANCED DATASET
class_0 = pd.DataFrame({
    'feature_1': np.random.normal(loc=0, scale=1, size=n_class_0),
    'feature_2': np.random.normal(loc=0, scale=1, size=n_class_0),
    'target': [0] * n_class_0
})

class_1 = pd.DataFrame({
    'feature_1': np.random.normal(loc=2, scale=1, size=n_class_1),
    'feature_2': np.random.normal(loc=2, scale=1, size=n_class_1),
    'target': [1] * n_class_1
})

# %%
df=pd.concat([class_0,class_1]).reset_index(drop=True)

# %%
df.head()
# Out:
#    feature_1  feature_2  target
# 0  -1.085631   1.131538       0
# 1   0.997345  -0.321510       0
# 2   0.282978   0.392148       0
# 3  -1.506295  -0.541998       0
# 4  -0.578600  -1.513386       0

# %%
df['target'].value_counts()
# Out:
# target
# 0    9000
# 1    1000
# Name: count, dtype: int64

# %%
# 1000 ko badhana h to up-sampling karenge 
# create 2 data frames 1. df['target']

df_minority=df[df['target']==1]
df_majority=df[df['target']==0]

# %%
from sklearn.utils import resample
df_minority_upsampled=resample(df_minority,replace=True, #Sample With replacement
        n_samples=len(df_majority),
        random_state=42
        )

# %%
df_minority_upsampled.shape
# Out:
# (9000, 3)

# %%
df_minority_upsampled.head()
# Out:
#       feature_1  feature_2  target
# 9102   2.342475   1.010997       1
# 9435   1.877956   3.418719       1
# 9860   2.220755   1.738277       1
# 9270   1.245965   2.464934       1
# 9106   1.059538   0.854590       1

# %%
df_upsampled = pd.concat([df_minority_upsampled, df_majority])
df_upsampled['target'].value_counts()
# Out:
# target
# 1    9000
# 0    9000
# Name: count, dtype: int64

# %%
# Down Sampling

# %% [markdown]
# ### DOWN SAMPLING

# %%
import pandas as pd

# Set the random seed for reproducibility
np.random.seed(123)

# Create a dataframe with two classes
n_samples = 1000
class_0_ratio = 0.9
n_class_0 = int(n_samples * class_0_ratio)
n_class_1 = n_samples - n_class_0

class_0 = pd.DataFrame({
    'feature_1': np.random.normal(loc=0, scale=1, size=n_class_0),
    'feature_2': np.random.normal(loc=0, scale=1, size=n_class_0),
    'target': [0] * n_class_0
})

class_1 = pd.DataFrame({
    'feature_1': np.random.normal(loc=2, scale=1, size=n_class_1),
    'feature_2': np.random.normal(loc=2, scale=1, size=n_class_1),
    'target': [1] * n_class_1
})

df = pd.concat([class_0, class_1]).reset_index(drop=True)

# Check the class distribution
print(df['target'].value_counts())
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %%
# Down Sampling 
df_minority=df[df['target']==1]
df_majority=df[df['target']==0]

# %%
from sklearn.utils import resample
df_majority_downsampled=resample(df_majority,replace=False,
n_samples=len(df_minority),
random_state=42
)

# %%
df_majority_downsampled.shape
# Out:
# (100, 3)

# %%
df_downsampled=pd.concat([df_minority,df_majority_downsampled])

# %%
df_downsampled.target.value_counts()
# Out:
# target
# 1    100
# 0    100
# Name: count, dtype: int64

# %% [markdown]
# ## Upsampling m  rows copy hoti h  isme kam chances hota h data ko loss hone ka .
# ## Downsampling m rows delete hoti h  brabar kerne ke liye jo ki ye acha nhi h isme data loss ho skata h .
