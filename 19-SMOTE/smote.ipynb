# %% [markdown]
# ###  SMOTE (Synthetic Minority Over-sampling Technique) is a technique used in machine learning to address imbalanced
# ### datasets where the minority class has significantly fewer instances than the majority class. SMOTE involves generating
# ### synthetic instances of the minority class by interpolating between existing instances.

# %%
from sklearn.datasets import make_classification

# %%
X,y=make_classification(n_samples=1000,n_redundant=0,n_features=2,n_clusters_per_class=1,
                   weights=[0.90],random_state=12)

# %%
import pandas as pd

# %%
df1=pd.DataFrame(X,columns=['f1','f2'])
df2=pd.DataFrame(y,columns=['target'])
final_df=pd.concat([df1,df2],axis=1)
final_df.head()
# Out:
#          f1        f2  target
# 0 -0.762898 -0.706808       0
# 1 -1.075436 -1.051162       0
# 2 -0.610115 -0.909802       0
# 3 -2.023284 -0.428945       1
# 4 -0.812921 -1.316206       0

# %%
final_df['target'].value_counts()
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(final_df['f1'],final_df['f2'],c=final_df['target'])

# %%
# !pip install imblearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# Collecting imbalanced-learn (from imblearn)
#   Downloading imbalanced_learn-0.14.2-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: numpy<3,>=1.25.2 in C:\Users\Laptop\AppData\Roaming\Python\Python312\site-packages (from imbalanced-learn->imblearn) (2.4.6)
# Requirement already satisfied: scipy<2,>=1.11.4 in C:\Users\Laptop\AppData\Roaming\Python\Python312\site-packages (from imbalanced-learn->imblearn) (1.16.1)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in C:\Users\Laptop\AppData\Roaming\Python\Python312\site-packages (from imbalanced-learn->imblearn) (1.7.2)
# Collecting sklearn-compat<0.2,>=0.1.6 (from imbalanced-learn->imblearn)
#   Downloading sklearn_compat-0.1.6-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: joblib<2,>=1.2.0 in C:\Users\Laptop\AppData\Roaming\Python\Python312\site-packages (from imbalanced-learn->imblearn) (1.5.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in C:\Users\Laptop\AppData\Roaming\Python\Python312\site-packages (from imbalanced-learn->imblearn) (3.6.0)
# Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Downloading imbalanced_learn-0.14.2-py3-none-any.whl (236 kB)
# Downloading sklearn_compat-0.1.6-py3-none-any.whl (22 kB)
# Installing collected packages: sklearn-compat, imbalanced-learn, imblearn
#
#    ---------------------------------------- 0/3 [sklearn-compat]
#    ---------------------------------------- 0/3 [sklearn-compat]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ---------------------------------------- 3/3 [imblearn]
#
# Successfully installed imbalanced-learn-0.14.2 imblearn-0.0 sklearn-compat-0.1.6
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: C:\Python312\python.exe -m pip install --upgrade pip

# %%
from imblearn.over_sampling import SMOTE

# %%
# Transform the Dataset using SMOTE
oversample=SMOTE()
X,y=oversample.fit_resample(final_df[['f1','f2']],final_df['target'])

# %%
X.shape
# Out:
# (1800, 2)

# %%
y.shape
# Out:
# (1800,)

# %%
len(y[y==0])
# Out:
# 900

# %%
len(y[y==1])
# Out:
# 900

# %%
df1= pd.DataFrame(X,columns=['f1','f2'])
df2= pd.DataFrame(y,columns=['target'])
oversample_df=pd.concat([df1,df2],axis=1)

# %%
plt.scatter(oversample_df['f1'],oversample_df['f2'],c=oversample_df['target'])
